# %%
import numpy as np
import pandas as pd

# %%
line5_data=pd.read_csv('5line_data')
trip_data=pd.read_csv('AGG-20150407.csv')

# %%
line5_data['timedif']=line5_data['transfered_outTime']-line5_data['transfered_inTime']

# %%
line5_data
# Out:
#        Unnamed: 0  Unnamed: 0.1      userID               inTime  inLine  \
# 0              39             0       65060  2015-04-07 18:02:07       4
# 1             189             0      100254  2015-04-07 17:28:04       1
# 2             237             0      110743  2015-04-07 20:43:32       1
# 3             595             0      192517  2015-04-07 21:25:50       1
# 4             643             0      212799  2015-04-07 07:31:01       5
# ...           ...           ...         ...                  ...     ...
# 67067     4288220             0  4000031744  2015-04-07 11:41:28       1
# 67068     4288260             0  4000033856  2015-04-07 10:01:53       4
# 67069     4288287             0  4000034885  2015-04-07 08:34:24       1
# 67070     4288553             0  4000040755  2015-04-07 20:40:43       9
# 67071     4288565             0  4000041052  2015-04-07 13:59:05       1
#
#       inStation              outTime  outLine outStation  transfered_inTime  \
# ...

# %%
trip_data
# Out:
#     Unnamed: 0                    0                    1                    2  \
# 0    startTime  2015-04-07 00:00:00  2015-04-07 00:10:00  2015-04-07 00:20:00
# 1      endTime  2015-04-07 00:10:00  2015-04-07 00:20:00  2015-04-07 00:30:00
# 2       111_in                    0                    0                    0
# 3      111_out                   69                   67                    0
# 4       112_in                    0                    0                    0
# ..         ...                  ...                  ...                  ...
# 623   1631_out                    0                    0                    0
# 624    1632_in                    0                    0                    0
# 625   1632_out                    0                    0                    0
# 626    1633_in                    0                    0                    0
# 627   1633_out                    0                    0                    0
#
# ...
